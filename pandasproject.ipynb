# %%
import pandas as pd
df=pd.read_csv("data.csv")
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df.isnull().sum()
# Out:
# Duration    0
# Date        1
# Pulse       0
# Maxpulse    0
# Calories    2
# dtype: int64

# %%
df["Calories"]=df["Calories"].ffill()
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df=df.dropna()

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
df["Maxpulse"].unique()
# Out:
# array([130, 145, 135, 175, 148, 127, 136, 134, 133, 124, 147, 120, 128,
#        132, 123, 112, 125, 131, 101, 126, 118, 129, 115], dtype=int64)

# %%
import seaborn as sns
sns.scatterplot(x="Duration",y="Maxpulse",data=df)
# Out:
# <Axes: xlabel='Duration', ylabel='Maxpulse'>

# %%
df[["Year","Month","day"]]=df["Date"].str.split("/",expand=True)
df
# Out:
# C:\Users\HARI K\AppData\Local\Temp\ipykernel_4264\821862256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Year","Month","day"]]=df["Date"].str.split("/",expand=True)
# C:\Users\HARI K\AppData\Local\Temp\ipykernel_4264\821862256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[["Year","Month","day"]]=df["Date"].str.split("/",expand=True)
# C:\Users\HARI K\AppData\Local\Temp\ipykernel_4264\821862256.py:1: SettingWithCopyWarning:
# ...

# %%
df.dropna()
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories   Year Month  day
# 0         60  '2020/12/01'    110       130     409.1  '2020    12  01'
# 1         60  '2020/12/02'    117       145     479.0  '2020    12  02'
# 2         60  '2020/12/03'    103       135     340.0  '2020    12  03'
# 3         45  '2020/12/04'    109       175     282.4  '2020    12  04'
# 4         45  '2020/12/05'    117       148     406.0  '2020    12  05'
# 5         60  '2020/12/06'    102       127     300.0  '2020    12  06'
# 6         60  '2020/12/07'    110       136     374.0  '2020    12  07'
# 7        450  '2020/12/08'    104       134     253.3  '2020    12  08'
# 8         30  '2020/12/09'    109       133     195.1  '2020    12  09'
# 9         60  '2020/12/10'     98       124     269.0  '2020    12  10'
# 10        60  '2020/12/11'    103       147     329.3  '2020    12  11'
# 11        60  '2020/12/12'    100       120     250.7  '2020    12  12'
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,8))
sns.barplot(x="Pulse",y="Maxpulse",data=df)
plt.show()

# %%
new=df.groupby("Maxpulse")["Calories"].sum()
plt.figure(figsize=(12,8))
new.plot(kind='line', color='green', linestyle=':', marker='o')
plt.show()

# %%
new_df=df.groupby("Pulse")["Calories"].sum()
plt.figure(figsize=(10,8))
new_df.plot(kind='pie', labels=new_df.index, autopct="%1.1f%%")
plt.show()

# %%
sns.boxplot(x="Maxpulse",data=df)
# Out:
# <Axes: xlabel='Maxpulse'>

# %%
import numpy as np
def replace_outliers(df,column):
    Q1=df[column].quantile(0.25)
    Q3=df[column].quantile(0.75)

    IQR=Q3-Q1

    upper_bound=Q3+1.5*IQR  
    lower_bound=Q1-1.5*IQR





    df.loc[:, column] = np.where(df[column] > upper_bound, upper_bound, df[column])
    df.loc[:, column] = np.where(df[column] < lower_bound, lower_bound, df[column])

replace_outliers(df,"Maxpulse")

# %%
sns.boxplot(x="Maxpulse",data=df)
# Out:
# <Axes: xlabel='Maxpulse'>

# %%
sns.barplot(df)
# Out:
# <Axes: >

# %%
df=pd.read_csv("dirty_cafe_sales.csv")

# %%
df
# Out:
#      Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0       TXN_1961373    Coffee        2            2.0         4.0
# 1       TXN_4977031      Cake        4            3.0        12.0
# 2       TXN_4271903    Cookie        4            1.0       ERROR
# 3       TXN_7034554     Salad        2            5.0        10.0
# 4       TXN_3160411    Coffee        2            2.0         4.0
# ...             ...       ...      ...            ...         ...
# 9995    TXN_7672686    Coffee        2            2.0         4.0
# 9996    TXN_9659401       NaN        3            NaN         3.0
# 9997    TXN_5255387    Coffee        4            2.0         8.0
# 9998    TXN_7695629    Cookie        3            NaN         3.0
# 9999    TXN_6170729  Sandwich        3            4.0        12.0
#
#       Payment Method  Location Transaction Date
# 0        Credit Card  Takeaway       2023-09-08
# 1               Cash  In-store       2023-05-16
# ...

# %%
df.isnull().sum()
# Out:
# Transaction ID         0
# Item                 333
# Quantity             138
# Price Per Unit       179
# Total Spent          173
# Payment Method      2579
# Location            3265
# Transaction Date     159
# dtype: int64

# %%
sns.scatterplot(x="Item",y="Quantity",data=df)
# Out:
# <Axes: xlabel='Item', ylabel='Quantity'>

# %%
df3=
